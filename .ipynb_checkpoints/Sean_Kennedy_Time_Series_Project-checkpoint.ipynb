# %%
import pandas as pd
import numpy as np
import tzlocal
import rpy2
import rpy2.robjects as ro
import rpy2.rinterface
from rpy2.robjects.packages import importr
from rpy2.robjects.lib import grdevices
from rpy2.robjects import r, pandas2ri
from rpy2.robjects.conversion import localconverter
from rpy2.robjects.packages import importr
from functools import partial
from rpy2.ipython import html
html.html_rdataframe=partial(html.html_rdataframe, table_class="docutils")
import pandas as pd
from rpy2.interactive import process_revents
from contextlib import contextmanager
from IPython.display import Image, display

#https://stackoverflow.com/questions/43110228/how-to-plot-inline-with-rpy2-in-jupyter-notebook
@contextmanager
def r_inline_plot(width=600, height=600, dpi=100):

    with grdevices.render_to_bytesio(grdevices.png, 
                                     width=width,
                                     height=height, 
                                     res=dpi) as b:

        yield

    data = b.getvalue()
    display(Image(data=data, format='png', embed=True))


pandas2ri.activate()

#/home/laurent/Desktop/software/python/py36_env/lib/python3.6/site-packages/rpy2-3.3.0.dev0-py3.6-linux-x86_64.egg/rpy2/robjects/pandas2ri.py:14: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
from pandas.core.index import Index as PandasIndex
#https://pandas.pydata.org/pandas-docs/version/0.22.0/r_interface.html
# Out:
# c:\users\skennedy\.virtualenvs\project-4s5smavk\lib\site-packages\rpy2\robjects\pandas2ri.py:17: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import Index as PandasIndex

# %% [markdown]
# ### Install TWSGE in rpy2

# %%
d = {'print.me': 'print_dot_me', 'print_me': 'print_uscore_me'}
tswge = importr(name='tswge', robject_translations=d, lib_loc='C://Users//skennedy//Documents//R//win-library//3.6')
base = importr('base')
print(base._libPaths())

# %%
# Out:
# [1] "C:/Program Files/R/R-3.6.2/library"

# %%
pzza = pd.read_csv('PZZA.tsv', sep='\t', header=None)

# %%
pzza
# Out:
#              0     1                     2     3           4           5   \
# 0    2020-03-13  PZZA       index_debit_qoq  2Q19  2019-04-01  2019-06-30
# 1    2020-03-13  PZZA                cs_yoy  2Q15  2015-03-30  2015-06-28
# 2    2020-03-13  PZZA      index_credit_qoq  3Q13  2013-07-01  2013-09-29
# 3    2020-03-13  PZZA     index_blended_qoq  1Q16  2015-12-28  2016-03-27
# 4    2020-03-13  PZZA  index_blended_values  3Q19  2019-07-01  2019-09-29
# ..          ...   ...                   ...   ...         ...         ...
# 323  2020-03-13  PZZA                cs_yoy  1Q18  2018-01-01  2018-04-01
# 324  2020-03-13  PZZA       index_debit_yoy  3Q15  2015-06-29  2015-09-27
# 325  2020-03-13  PZZA   index_credit_values  4Q18  2018-10-01  2018-12-30
# 326  2020-03-13  PZZA   index_credit_values  2Q13  2013-04-01  2013-06-30
# 327  2020-03-13  PZZA      index_credit_yoy  2Q14  2014-03-31  2014-06-29
#
#          6       7       8        9   ...     13      14  15  16  17  18  19  \
# ...

# %%
bonds = pd.read_csv('10_year_bond_rate_2010-2015.csv')

# %%
bonds['Adj Close']
# Out:
# 0       3.841
# 1       3.755
# 2       3.808
# 3       3.822
# 4       3.808
#         ...
# 1504    2.243
# 1505    2.225
# 1506    2.307
# 1507    2.303
# 1508    2.269
# Name: Adj Close, Length: 1509, dtype: float64

# %%
with r_inline_plot(width=1024, height=896, dpi=150):
     tswge.plotts_sample_wge(bonds_r)
#plotts[0]
#r.plotts_sample_wge(bonds_r)
#f = r.plot(plotts[0])
#f

# %% [markdown]
# https://rpy2.github.io/doc/latest/html/pandas.html

# %%
with localconverter(ro.default_converter + pandas2ri.converter):
    pd_from_r_df = ro.conversion.rpy2py(r_df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-dc5fb831cf92> in <module>
#       1 with localconverter(ro.default_converter + pandas2ri.converter):
# ----> 2     pd_from_r_df = ro.conversion.rpy2py(r_df)
#
# AttributeError: module 'rpy2.robjects.conversion' has no attribute 'rpy2py'
